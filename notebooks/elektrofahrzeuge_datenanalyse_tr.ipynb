# %% [markdown]
# # 1. Veri Seti Hakkında
#
# ![1.png](attachment:de315075-5956-4d9a-8262-7d0710718b8a.png)
#
# Bu veri seti, 2020 ile 2026 yılları arasında üretilmiş elektrikli araç (EV) modellerine ait teknik ve ticari performans verilerini içermektedir. Veri seti toplamda 2000 gözlem ve 24 sütun içermekte olup, her satır belirli bir markanın belirli bir yıl ve varyanttaki (base, long range, premium, performance, standard) modelini temsil etmektedir.
#
# **Veri setinde yer alan markalar şunlardır:**
#
# - **Almanya:** Audi, BMW, Mercedes, Porsche, Volkswagen
# - **ABD:** Fisker, Ford, GM/Chevrolet, Lucid, Rivian, Tesla
# - **Japonya:** Honda, Toyota
# - **Güney Kore:** Hyundai, Kia
# - **Çin:** BYD, NIO, Xiaomi
# - **İsveç:** Polestar, Volvo
#
# **Veri setindeki 24 sütunun anlamları aşağıdaki gibidir:**
#
# <table style='text-align: left; margin-left: 0;'>
#   <tr>
#     <th>Sütun Adı</th>
#     <th>Açıklama</th>
#   </tr>
#   <tr>
#     <td><strong>brand</strong></td>
#     <td>Aracın markası</td>
#   </tr>
#   <tr>
#     <td><strong>model</strong></td>
#     <td>Aracın model adı</td>
#   </tr>
#   <tr>
#     <td><strong>year</strong></td>
#     <td>Model yılı</td>
#   </tr>
#   <tr>
#     <td><strong>variant</strong></td>
#     <td>Model varyantı (base, standard, long range, premium, performance)</td>
#   </tr>
#   <tr>
#     <td><strong>price_usd</strong></td>
#     <td>Aracın satış fiyatı (USD)</td>
#   </tr>
#   <tr>
#     <td><strong>battery_capacity_kwh</strong></td>
#     <td>Batarya kapasitesi (kWh)</td>
#   </tr>
#   <tr>
#     <td><strong>range_miles</strong></td>
#     <td>Tam şarjla gidilebilen mesafe (mil)</td>
#   </tr>
#   <tr>
#     <td><strong>charging_speed_kw</strong></td>
#     <td>Maksimum hızlı şarj gücü (kW)</td>
#   </tr>
#   <tr>
#     <td><strong>acceleration_0_60_mph</strong></td>
#     <td>0-60 mph hızlanma süresi (saniye)</td>
#   </tr>
#   <tr>
#     <td><strong>top_speed_mph</strong></td>
#     <td>Azami hız (mph)</td>
#   </tr>
#   <tr>
#     <td><strong>horsepower</strong></td>
#     <td>Motor gücü (beygir gücü, hp)</td>
#   </tr>
#   <tr>
#     <td><strong>torque_nm</strong></td>
#     <td>Motor torku (Nm)</td>
#   </tr>
#   <tr>
#     <td><strong>drive_type</strong></td>
#     <td>Çekiş tipi (FWD, RWD, AWD)</td>
#   </tr>
#   <tr>
#     <td><strong>seating_capacity</strong></td>
#     <td>Koltuk kapasitesi</td>
#   </tr>
#   <tr>
#     <td><strong>body_type</strong></td>
#     <td>Kasa tipi (sedan, SUV, hatchback, coupe, van, truck)</td>
#   </tr>
#   <tr>
#     <td><strong>cargo_volume_cubic_ft</strong></td>
#     <td>Bagaj/yük hacmi (feet küp)</td>
#   </tr>
#   <tr>
#     <td><strong>weight_kg</strong></td>
#     <td>Aracın ağırlığı (kg)</td>
#   </tr>
#   <tr>
#     <td><strong>safety_rating</strong></td>
#     <td>Güvenlik puanı (1-5 arası)</td>
#   </tr>
#   <tr>
#     <td><strong>autopilot_level</strong></td>
#     <td>Otonom sürüş seviyesi (0-3 arası)</td>
#   </tr>
#   <tr>
#     <td><strong>country_of_origin</strong></td>
#     <td>Markanın menşei ülke</td>
#   </tr>
#   <tr>
#     <td><strong>market_segment</strong></td>
#     <td>Pazar segmenti (budget, mid-range, premium, luxury)</td>
#   </tr>
#   <tr>
#     <td><strong>annual_sales_units</strong></td>
#     <td>Yıllık satış adedi</td>
#   </tr>
#   <tr>
#     <td><strong>customer_rating</strong></td>
#     <td>Müşteri memnuniyet puanı (1-5 arası)</td>
#   </tr>
#   <tr>
#     <td><strong>warranty_years</strong></td>
#     <td>Garanti süresi (yıl)</td>
#   </tr>
# </table>

# %% [markdown]
# # 2. Kütüphaneleri İçe Aktarma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 11
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 120)
warnings.filterwarnings('ignore')

# %% [markdown]
# # 3. Veri Setini Yükleme

# %%
df = pd.read_csv('../data/electric_vehicle.csv')

df
# Out:
#              brand           model  year      variant  price_usd  battery_capacity_kwh  range_miles  \
# 0       Volkswagen        ID. Buzz  2023  Performance  104880.80                 118.7        400.0
# 1           Toyota  bZ Compact SUV  2022      Premium   48217.41                  58.8        219.0
# 2     GM/Chevrolet         Bolt EV  2024      Premium   49651.12                  58.2        225.0
# 3              Kia     Sportage EV  2024   Long Range   38131.56                 102.5        349.0
# 4            Tesla         Model 3  2022   Long Range  144079.87                  93.9        314.0
# ...            ...             ...   ...          ...        ...                   ...          ...
# 1995           BMW              i3  2023   Long Range  122665.71                 102.1        360.0
# 1996        Toyota            bZ4X  2024  Performance   66816.55                 110.6        367.0
# ...

# %% [markdown]
# # 4. Veri Setine Genel Bakış

# %%
df.head()
# Out:
#           brand           model  year      variant  price_usd  battery_capacity_kwh  range_miles  charging_speed_kw  \
# 0    Volkswagen        ID. Buzz  2023  Performance  104880.80                 118.7        400.0              234.5
# 1        Toyota  bZ Compact SUV  2022      Premium   48217.41                  58.8        219.0              148.1
# 2  GM/Chevrolet         Bolt EV  2024      Premium   49651.12                  58.2        225.0              104.9
# 3           Kia     Sportage EV  2024   Long Range   38131.56                 102.5        349.0               66.5
# 4         Tesla         Model 3  2022   Long Range  144079.87                  93.9        314.0              298.5
#
#    acceleration_0_60_mph  top_speed_mph  horsepower  torque_nm drive_type  seating_capacity body_type  \
# 0                   3.04          195.0      1000.0      895.0        AWD                 7     Truck
# ...

# %%
df.tail()
# Out:
#        brand    model  year      variant  price_usd  battery_capacity_kwh  range_miles  charging_speed_kw  \
# 1995     BMW       i3  2023   Long Range  122665.71                 102.1        360.0               92.0
# 1996  Toyota     bZ4X  2024  Performance   66816.55                 110.6        367.0              236.3
# 1997   Tesla  Model 3  2025   Long Range   49281.26                  90.6        325.0              325.6
# 1998   Tesla  Model X  2026      Premium  139665.73                  70.7        248.0              330.7
# 1999     BYD      Qin  2025      Premium   47547.88                  67.4        246.0               67.2
#
#       acceleration_0_60_mph  top_speed_mph  horsepower  torque_nm drive_type  seating_capacity  body_type  \
# 1995                   4.21          190.0      1000.0      935.0        FWD                 5  Hatchback
# 1996                   4.25          181.0       783.0      733.0        AWD                 5  Hatchback
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   brand                  2000 non-null   object
#  1   model                  2000 non-null   object
#  2   year                   2000 non-null   int64
#  3   variant                2000 non-null   object
#  4   price_usd              2000 non-null   float64
#  5   battery_capacity_kwh   2000 non-null   float64
#  6   range_miles            2000 non-null   float64
#  7   charging_speed_kw      2000 non-null   float64
#  8   acceleration_0_60_mph  2000 non-null   float64
#  9   top_speed_mph          2000 non-null   float64
#  10  horsepower             2000 non-null   float64
#  11  torque_nm              2000 non-null   float64
#  12  drive_type             2000 non-null   object
#  13  seating_capacity       2000 non-null   int64
# ...

# %%
df.shape
# Out:
# (2000, 24)

# %%
df.columns
# Out:
# Index(['brand', 'model', 'year', 'variant', 'price_usd', 'battery_capacity_kwh', 'range_miles', 'charging_speed_kw',
#        'acceleration_0_60_mph', 'top_speed_mph', 'horsepower', 'torque_nm', 'drive_type', 'seating_capacity',
#        'body_type', 'cargo_volume_cubic_ft', 'weight_kg', 'safety_rating', 'autopilot_level', 'country_of_origin',
#        'market_segment', 'annual_sales_units', 'customer_rating', 'warranty_years'],
#       dtype='object')

# %%
df.dtypes
# Out:
# brand                     object
# model                     object
# year                       int64
# variant                   object
# price_usd                float64
# battery_capacity_kwh     float64
# range_miles              float64
# charging_speed_kw        float64
# acceleration_0_60_mph    float64
# top_speed_mph            float64
# horsepower               float64
# torque_nm                float64
# drive_type                object
# seating_capacity           int64
# body_type                 object
# cargo_volume_cubic_ft    float64
# weight_kg                float64
# safety_rating              int64
# autopilot_level            int64
# country_of_origin         object
# market_segment            object
# annual_sales_units         int64
# customer_rating          float64
# warranty_years             int64
# dtype: object

# %%
df.describe()
# Out:
#               year      price_usd  battery_capacity_kwh  range_miles  charging_speed_kw  acceleration_0_60_mph  \
# count  2000.000000    2000.000000           2000.000000  2000.000000        2000.000000            2000.000000
# mean   2024.028500   78873.907150             74.662800   261.825500         155.206300               5.630635
# std       1.410561   35296.621782             20.082879    71.028238          80.982301               1.417733
# min    2020.000000   16394.330000             40.000000   150.000000          50.000000               2.500000
# 25%    2023.000000   52325.920000             58.475000   204.000000          90.975000               4.620000
# 50%    2024.000000   73013.015000             75.100000   261.000000         132.100000               5.670000
# 75%    2025.000000   99780.157500             87.550000   310.000000         217.300000               6.770000
# ...

# %%
df.isnull().sum()
# Out:
# brand                    0
# model                    0
# year                     0
# variant                  0
# price_usd                0
# battery_capacity_kwh     0
# range_miles              0
# charging_speed_kw        0
# acceleration_0_60_mph    0
# top_speed_mph            0
# horsepower               0
# torque_nm                0
# drive_type               0
# seating_capacity         0
# body_type                0
# cargo_volume_cubic_ft    0
# weight_kg                0
# safety_rating            0
# autopilot_level          0
# country_of_origin        0
# market_segment           0
# annual_sales_units       0
# customer_rating          0
# warranty_years           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
numerical_columns = df.select_dtypes(include=['number']).columns

numerical_columns
# Out:
# Index(['year', 'price_usd', 'battery_capacity_kwh', 'range_miles', 'charging_speed_kw', 'acceleration_0_60_mph',
#        'top_speed_mph', 'horsepower', 'torque_nm', 'seating_capacity', 'cargo_volume_cubic_ft', 'weight_kg',
#        'safety_rating', 'autopilot_level', 'annual_sales_units', 'customer_rating', 'warranty_years'],
#       dtype='object')

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

categorical_columns
# Out:
# Index(['brand', 'model', 'variant', 'drive_type', 'body_type', 'country_of_origin', 'market_segment'], dtype='object')

# %% [markdown]
# # 5. Keşifsel Veri Analizi (EDA)
# ## 5.1. Sayısal Değişken Analizi
# ### 5.1.1. Price

# %%
plt.hist(df["price_usd"], bins=30)

plt.title("Araç Fiyatlarının Dağılımı")
plt.xlabel("Fiyat (USD)")
plt.ylabel("Frekans")

plt.show()

# %%
plt.boxplot(df["price_usd"])

plt.title("Araç Fiyatlarının Kutu Grafiği")
plt.ylabel("Fiyat (USD)")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Araç fiyatları ağırlıklı olarak <strong>50.000–100.000 USD</strong> aralığında yoğunlaşmaktadır.</li>
#     <li>Histogram ve kutu grafiği, <code>describe()</code> çıktısındaki ortalama (<strong>≈78.874 USD</strong>) ve medyan (<strong>≈73.013 USD</strong>) değerlerini doğrulamaktadır. Ortalama değerin medyandan yüksek olması, dağılımın <strong>sağa çarpık (right-skewed)</strong> olduğunu göstermektedir.</li>
#     <li>Kutu grafiğinde üst bıyığın daha uzun olması ve üst tarafta daha fazla gözlem bulunması da sağa çarpık dağılımı desteklemektedir.</li>
#     <li><strong>200.000 USD</strong> üzerindeki araçlar veri setinde az sayıda yer almakta ve kutu grafiğinde potansiyel aykırı değer olarak görünmektedir. Ancak elektrikli araç pazarındaki lüks ve yüksek performanslı modeller göz önünde bulundurulduğunda, bu gözlemler veri setinin doğal bir parçası olarak değerlendirilebilir.</li>
#     <li>Genel olarak price_usd değişkeni dengeli ve tutarlı bir dağılım sergilemekte olup, veri temizleme aşamasında müdahale gerektiren belirgin bir durum bulunmamaktadır.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.2. Battery Capacity

# %%
plt.hist(df["battery_capacity_kwh"], bins=20)

plt.title("Batarya Kapasitesinin Dağılımı")
plt.xlabel("Batarya Kapasitesi (kWh)")
plt.ylabel("Frekans")

plt.show()

# %%
plt.boxplot(df["battery_capacity_kwh"])

plt.title("Batarya Kapasitesinin Kutu Grafiği")
plt.ylabel("Batarya Kapasitesi (kWh)")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Batarya kapasiteleri yaklaşık <strong>40–120 kWh</strong> aralığında dağılım göstermektedir. Bu değerler günümüzdeki elektrikli araçlar için gerçekçi ve beklenen bir aralığı temsil etmektedir.</li>
#     <li>Histogram ve kutu grafiği, batarya kapasitelerinin büyük bölümünün <strong>60–90 kWh</strong> aralığında yoğunlaştığını doğrulamaktadır.</li>
#     <li><code>describe()</code> çıktısındaki ortalama (<strong>≈74.66 kWh</strong>) ve medyan (<strong>≈75 kWh</strong>) değerlerinin birbirine oldukça yakın olması, dağılımın belirgin bir sağ veya sol çarpıklık göstermediğini desteklemektedir.</li>
#     <li>Boxplot üzerinde istatistiksel olarak potansiyel aykırı değer bulunmamakta olup, veri giriş hatasına veya olağan dışı gözlemlere işaret eden belirgin bir bulgu görülmemektedir.</li>
#     <li>Genel olarak battery_capacity_kwh değişkeni dengeli, tutarlı ve veri kalitesi açısından güvenilir bir dağılım sergilemektedir.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.3. Range

# %%
sns.histplot(data=df, x='range_miles', bins=20)

plt.title("Araç Menzilinin Dağılımı")
plt.xlabel("Menzil (Mil)")
plt.ylabel("Frekans")

plt.show()

# %%
plt.boxplot(df["range_miles"])

plt.title("Araç Menzilinin Kutu Grafiği")
plt.ylabel("Menzil (Mil)")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Araç menzilleri yaklaşık <strong>150–450 mil</strong> aralığında dağılım göstermektedir. Bu değerler günümüz elektrikli araç pazarıyla uyumlu ve gerçekçi bir aralığı temsil etmektedir.</li>
#     <li>Histogram ve kutu grafiği, araç menzillerinin büyük bölümünün <strong>240–300 mil</strong> aralığında yoğunlaştığını doğrulamaktadır. <code>describe()</code> çıktısındaki medyan değerin yaklaşık <strong>260 mil</strong> olması da bu bulguyu desteklemektedir.</li>
#     <li>Dağılım <strong>hafif sağa çarpık (right-skewed)</strong> bir yapı sergilemektedir. 350 mil üzerindeki araç sayısı giderek azalırken, 400 mil üzerindeki araçlar veri setinde daha sınırlı sayıda yer almaktadır.</li>
#     <li>Boxplot üzerinde istatistiksel olarak potansiyel aykırı değer bulunmamakta olup, yaklaşık <strong>150–450 mil</strong> aralığındaki değerler veri giriş hatasına işaret etmemektedir.</li>
#     <li>Genel olarak range_miles değişkeni dengeli ve tutarlı bir dağılım sergilemekte olup, veri temizleme aşamasında müdahale gerektiren belirgin bir durum bulunmamaktadır.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.4. Horsepower

# %%
sns.histplot(data=df, x="horsepower", bins=20)

plt.axvline(df["horsepower"].mean(), color="red", linestyle="--", label="Ortalama")
plt.axvline(df["horsepower"].median(), color="green", linestyle="-", label="Medyan")

plt.title("Beygir Gücünün Dağılımı")
plt.xlabel("Beygir Gücü (HP)")
plt.ylabel("Frekans")

plt.legend()

plt.show()

# %%
df["horsepower"].describe()
# Out:
# count    2000.000000
# mean      665.744000
# std       267.124838
# min       150.000000
# 25%       442.750000
# 50%       683.000000
# 75%       939.250000
# max      1000.000000
# Name: horsepower, dtype: float64

# %%
df["horsepower"].value_counts().head(10)
# Out:
# horsepower
# 1000.0    422
# 150.0      20
# 376.0       6
# 378.0       6
# 752.0       6
# 493.0       6
# 335.0       6
# 505.0       6
# 586.0       6
# 716.0       6
# Name: count, dtype: int64

# %%
plt.boxplot(df["horsepower"])

plt.title("Beygir Gücünün Kutu Grafiği")
plt.ylabel("Beygir Gücü (HP)")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Beygir gücü değerleri yaklaşık <strong>150–1000 HP</strong> aralığında dağılım göstermektedir.</li>
#     <li>Histogram ve kutu grafiği, <code>describe()</code> çıktısındaki ortalama (<strong>≈665.74 HP</strong>) ve medyan (<strong>683 HP</strong>) değerlerini doğrulamaktadır. Medyanın ortalamadan biraz yüksek olması, dağılımın <strong>hafif sola çarpık (left-skewed)</strong> olduğunu göstermektedir.</li>
#     <li>Boxplot üzerinde istatistiksel olarak potansiyel aykırı değer bulunmamaktadır. Bu durum, 1000 HP değerindeki yoğunlaşmanın IQR yöntemine göre aykırı değer olarak değerlendirilmediğini göstermektedir.</li>
#     <li><code>value_counts()</code> analizi sonucunda <strong>1000 HP</strong> değerine sahip <strong>422 araç</strong> bulunduğu görülmüştür. Bu yoğunluk, veri setinin sentetik yapısından veya veri oluşturulurken uygulanan üst sınır (<em>ceiling effect</em>) nedeniyle oluşmuş olabilir.</li>
#     <li>Genel olarak horsepower değişkeni veri temizleme açısından müdahale gerektiren belirgin bir sorun içermemektedir. Ancak 1000 HP seviyesindeki yoğunlaşma, sonraki analizlerde yorumlanırken dikkate alınmalıdır.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.5. Annual Sales Units

# %%
sns.histplot(data=df, x="annual_sales_units", bins=20)

plt.axvline(df["annual_sales_units"].mean(), color="red", linestyle="--", linewidth=2, label="Ortalama")
plt.axvline(df["annual_sales_units"].median(), color="green", linewidth=2, label="Medyan")

plt.title("Yıllık Satış Adedinin Dağılımı")
plt.xlabel("Yıllık Satış Adedi")
plt.ylabel("Frekans")

plt.legend()

plt.show()

# %%
sns.boxplot(y=df["annual_sales_units"])

plt.title("Yıllık Satış Adedinin Kutu Grafiği")
plt.ylabel("Yıllık Satış Adedi")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Yıllık satış adetleri yaklaşık <strong>0–500.000</strong> aralığında dağılım göstermektedir. Araçların büyük bölümü <strong>200.000</strong> adedin altında yoğunlaşmaktadır.</li>
#     <li>Histogram ve kutu grafiği birlikte değerlendirildiğinde, medyanın ortalamadan daha düşük olduğu görülmektedir. Bu durum, yüksek satış değerlerinin ortalamayı yukarı çekmesi nedeniyle dağılımın <strong>sağa çarpık (right-skewed)</strong> olduğunu göstermektedir.</li>
#     <li>Kutu grafiği, yaklaşık <strong>440.000–500.000</strong> aralığında istatistiksel olarak potansiyel aykırı değerler bulunduğunu göstermektedir. Bu değerler, veri giriş hatasına işaret etmekten ziyade pazarda olağanüstü satış başarısı gösteren modelleri temsil ediyor olabilir.</li>
#     <li>Histogramda yüksek satış adetlerine sahip araç sayısının sınırlı olduğu, buna karşılık düşük ve orta satış seviyelerindeki araçların veri setinde daha fazla yer aldığı görülmektedir.</li>
#     <li>Genel olarak annual_sales_units değişkeni veri temizleme açısından müdahale gerektiren belirgin bir sorun içermemektedir. Ancak yüksek satış değerleri sonraki analizlerde ortalamayı etkileyebileceğinden yorumlanırken dikkate alınmalıdır.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.6. Customer Rating

# %%
sns.histplot(data=df, x="customer_rating", bins=20)

plt.axvline(df["customer_rating"].mean(), color="red", linestyle="--", linewidth=2, label="Ortalama")
plt.axvline(df["customer_rating"].median(), color="green", linewidth=2, label="Medyan")

plt.title("Müşteri Puanının Dağılımı")
plt.xlabel("Müşteri Puanı")
plt.ylabel("Frekans")

plt.legend()

plt.show()

# %%
sns.boxplot(y=df["customer_rating"])

plt.title("Müşteri Puanının Kutu Grafiği")
plt.ylabel("Müşteri Puanı")

plt.show()

# %%
df["customer_rating"].describe()
# Out:
# count    2000.000000
# mean        3.572045
# std         0.270398
# min         3.000000
# 25%         3.380000
# 50%         3.560000
# 75%         3.750000
# max         4.510000
# Name: customer_rating, dtype: float64

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Müşteri puanları <strong>3,0–4,5</strong> aralığında dağılım göstermektedir. Değerlerin büyük bölümü <strong>3,4–3,8</strong> aralığında yoğunlaşmaktadır.</li>
#     <li>Histogram ve kutu grafiği, <code>describe()</code> çıktısındaki ortalama (<strong>≈3,57</strong>) ve medyan (<strong>3,56</strong>) değerlerini doğrulamaktadır. Ortalama ve medyanın birbirine oldukça yakın olması, dağılımın genel olarak dengeli olduğunu göstermektedir.</li>
#     <li>Dağılım hafif <strong>sağa çarpık (right-skewed)</strong> bir yapı sergilemektedir. 4,0 üzerindeki müşteri puanlarının sayısı giderek azalmakta, 4,3 ve üzerindeki değerler ise daha sınırlı görülmektedir.</li>
#     <li>Kutu grafiği, yaklaşık <strong>4,3–4,5</strong> aralığında istatistiksel olarak potansiyel aykırı değerler bulunduğunu göstermektedir. Ancak bu değerler müşteri memnuniyetinin oldukça yüksek olduğu modelleri temsil edebileceğinden veri hatası olarak değerlendirilmemelidir.</li>
#     <li>Genel olarak customer_rating değişkeni tutarlı bir dağılım sergilemekte olup, veri temizleme aşamasında müdahale gerektiren belirgin bir durum bulunmamaktadır.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.2. Kategorik Değişken Analizi
# ### 5.2.1. Brand

# %%
df["brand"].value_counts()
# Out:
# brand
# Tesla           434
# BYD             282
# Volkswagen      194
# Kia             166
# Hyundai         152
# BMW             150
# GM/Chevrolet    143
# Ford            129
# Mercedes         96
# Audi             77
# Toyota           41
# Rivian           37
# Fisker           25
# NIO              23
# Porsche          14
# Volvo            12
# Polestar          9
# Xiaomi            8
# Lucid             6
# Honda             2
# Name: count, dtype: int64

# %%
sns.countplot(data=df, y="brand", order=df["brand"].value_counts().index)

plt.title("Markalara Göre Araç Sayısı")
plt.xlabel("Araç Sayısı")
plt.ylabel("Marka")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Veri setinde toplam <strong>20 farklı araç markası</strong> bulunmaktadır. Marka dağılımı dengeli olmayıp, belirli markalar veri setinde daha fazla temsil edilmektedir.</li>
#     <li><strong>Tesla</strong>, <strong>434</strong> araç ile veri setinde en fazla temsil edilen marka konumundadır. Onu sırasıyla <strong>BYD (282)</strong> ve <strong>Volkswagen (194)</strong> takip etmektedir.</li>
#     <li>Grafik incelendiğinde araçların büyük bölümünün ilk birkaç marka üzerinde yoğunlaştığı, buna karşılık Lucid, Xiaomi, Polestar ve Honda gibi markaların veri setinde oldukça sınırlı sayıda yer aldığı görülmektedir.</li>
#     <li>Bu dağılım, veri setinin gerçek pazar paylarını birebir temsil ettiğini göstermemektedir. Bazı markaların daha fazla gözleme sahip olması, veri oluşturma sürecindeki dağılımdan kaynaklanıyor olabilir.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.2.2. Body Type

# %%
df["body_type"].value_counts()
# Out:
# body_type
# Truck        427
# SUV          364
# Hatchback    324
# Coupe        303
# Sedan        301
# Van          281
# Name: count, dtype: int64

# %%
sns.countplot(data=df, y="body_type", order=df["body_type"].value_counts().index)

plt.title("Kasa Tiplerine Göre Araç Sayısı")
plt.xlabel("Araç Sayısı")
plt.ylabel("Kasa Tipi")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Veri setinde toplam <strong>6 farklı kasa tipi</strong> bulunmaktadır. Kasa tipleri genel olarak dengeli bir dağılım sergilemektedir.</li>
#     <li><strong>Truck (427)</strong> veri setinde en fazla temsil edilen kasa tipi olup, onu sırasıyla <strong>SUV (364)</strong> ve <strong>hatchback (324)</strong> takip etmektedir.</li>
#     <li>Coupe, sedan ve van kategorileri de benzer sayıda gözlem içermekte olup, veri setinde belirgin şekilde eksik temsil edilen bir kasa tipi bulunmamaktadır.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.2.3. Drive Type

# %%
df["drive_type"].value_counts()
# Out:
# drive_type
# AWD    754
# RWD    678
# FWD    568
# Name: count, dtype: int64

# %%
sns.countplot(data=df, y="drive_type", order=df["drive_type"].value_counts().index)

plt.title("Çekiş Tiplerine Göre Araç Sayısı")
plt.xlabel("Araç Sayısı")
plt.ylabel("Çekiş Tipi")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Veri setinde toplam <strong>3 farklı çekiş tipi</strong> bulunmaktadır. Çekiş tipleri genel olarak dengeli bir dağılım sergilemektedir.</li>
#     <li><strong>AWD (754)</strong>, veri setinde en fazla temsil edilen çekiş tipi olup, onu <strong>RWD (678)</strong> ve <strong>FWD (568)</strong> takip etmektedir.</li>
#     <li>Her üç çekiş tipi de yüksek sayıda gözlem içerdiğinden, sonraki analizlerde çekiş tipleri arasında güvenilir karşılaştırmalar yapılmasına olanak sağlamaktadır.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.2.4. Market Segment

# %%
df["market_segment"].value_counts()
# Out:
# market_segment
# Premium      712
# Mid-range    642
# Luxury       495
# Budget       151
# Name: count, dtype: int64

# %%
sns.countplot(data=df, y="market_segment", order=df["market_segment"].value_counts().index)

plt.title("Pazar Segmentlerine Göre Araç Sayısı")
plt.xlabel("Araç Sayısı")
plt.ylabel("Pazar Segmenti")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Veri setinde toplam <strong>4 farklı pazar segmenti</strong> bulunmaktadır. Araçların büyük bölümü premium ve mid-range segmentlerinde yoğunlaşmaktadır.</li>
#     <li><strong>Premium (712)</strong> segmenti veri setinde en fazla temsil edilen kategori olup, onu <strong>mid-range (642)</strong> ve <strong>luxury (495)</strong> segmentleri takip etmektedir.</li>
#     <li><strong>Budget (151)</strong> segmenti ise diğer segmentlere kıyasla daha az sayıda araç içermektedir. Bu durum, veri setinin daha çok orta ve üst segment elektrikli araçlara odaklandığını göstermektedir.</li>
#     <li>Pazar segmenti değişkeni, sonraki analizlerde fiyat, menzil, satış adedi ve müşteri puanı gibi performans göstergeleriyle birlikte değerlendirilerek segmentler arasındaki farklılıkların incelenmesinde kullanılacaktır.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.3. Değişkenler Arası İlişki Analizi

# %%
corr = df.select_dtypes(include="number").corr()

sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")

plt.title("Sayısal Değişkenler Arasındaki Korelasyon Matrisi")

plt.show()

# %% [markdown]
# ### 5.3.1. Range ↔ Battery Capacity

# %%
sns.regplot(data=df, x="battery_capacity_kwh", y="range_miles", scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})

plt.title("Batarya Kapasitesi ile Menzil Arasındaki İlişki")
plt.xlabel("Batarya Kapasitesi (kWh)")
plt.ylabel("Menzil (Mil)")

plt.show()

# %%
df["battery_capacity_kwh"].corr(df["range_miles"])
# Out:
# np.float64(0.9778585581959761)

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Scatter grafiği, batarya kapasitesi ile araç menzili arasında çok güçlü doğrusal bir ilişki olduğunu göstermektedir. Noktaların regresyon çizgisi etrafında yoğun şekilde kümelenmesi bu ilişkiyi açıkça desteklemektedir.</li>
#     <li>Hesaplanan Pearson korelasyon katsayısı <strong>r = 0.978</strong> olup, iki değişken arasında <strong>çok güçlü pozitif</strong> bir ilişki bulunduğunu göstermektedir.</li>
#     <li>Batarya kapasitesi arttıkça araçların menzili de belirgin şekilde artmaktadır. Bu durum, elektrikli araçlarda daha büyük batarya paketlerinin daha uzun sürüş mesafesi sağladığı teknik beklentiyle uyumludur.</li>
#     <li>Bu analiz, batarya kapasitesinin araç menzilini açıklayan en önemli değişkenlerden biri olduğunu göstermektedir. Heatmap analizinde gözlenen en güçlü ilişkilerden biri de bu değişken çifti arasında elde edilmiştir.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.2. Price ↔ Horsepower

# %%
sns.regplot(data=df, x="horsepower", y="price_usd", scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})

plt.title("Motor Gücü ile Araç Fiyatı Arasındaki İlişki")
plt.xlabel("Motor Gücü (HP)")
plt.ylabel("Araç Fiyatı (USD)")

plt.show()

# %%
df["horsepower"].corr(df["price_usd"])
# Out:
# np.float64(0.7647243074137059)

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Scatter grafiği, motor gücü ile araç fiyatı arasında belirgin bir pozitif doğrusal ilişki olduğunu göstermektedir. Motor gücü arttıkça araç fiyatı da genel olarak artmaktadır.</li>
#     <li>Hesaplanan Pearson korelasyon katsayısı <strong>r = 0.765</strong> olup, iki değişken arasında <strong>güçlü pozitif</strong> bir ilişki bulunduğunu göstermektedir.</li>
#     <li>Grafikte özellikle <strong>1000 HP</strong> değerinde yoğun bir veri kümelenmesi görülmektedir. Bu durum, veri setindeki maksimum motor gücü sınırından kaynaklanan bir tavan etkisini göstermektedir.</li>
#     <li>Aynı motor gücüne sahip araçların farklı fiyat seviyelerinde bulunması, araç fiyatının yalnızca motor gücüyle açıklanamayacağını göstermektedir. Marka, donanım seviyesi, teknoloji, batarya özellikleri ve pazar segmenti gibi diğer faktörler de fiyat üzerinde önemli rol oynamaktadır.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.3. Range ↔ Customer Rating

# %%
sns.regplot(data=df, x="range_miles", y="customer_rating", scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})

plt.title("Araç Menzili ile Müşteri Puanı Arasındaki İlişki")
plt.xlabel("Menzil (Mil)")
plt.ylabel("Müşteri Puanı")

plt.show()

# %%
df["range_miles"].corr(df["customer_rating"])
# Out:
# np.float64(0.6681371738521219)

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Scatter grafiği, araç menzili ile müşteri puanı arasında pozitif yönlü bir ilişki olduğunu göstermektedir. Araç menzili arttıkça müşteri puanlarının da genel olarak yükselme eğiliminde olduğu görülmektedir.</li>
#     <li>Hesaplanan Pearson korelasyon katsayısı <strong>r = 0.668</strong> olup, iki değişken arasında <strong>orta-güçlü pozitif</strong> bir ilişki bulunduğunu göstermektedir.</li>
#     <li>Grafikte aynı menzil değerine sahip araçların farklı müşteri puanları aldığı görülmektedir. Bu durum, müşteri memnuniyetinin yalnızca araç menziliyle açıklanamayacağını; marka, fiyat, performans, donanım seviyesi ve kullanıcı deneyimi gibi diğer faktörlerin de etkili olduğunu göstermektedir.</li>
#     <li>Bununla birlikte, elde edilen pozitif ilişki uzun menzilin müşteri memnuniyetini artıran önemli özelliklerden biri olabileceğini göstermektedir. Özellikle elektrikli araç kullanıcıları için menzil, satın alma kararını ve kullanıcı deneyimini etkileyen temel faktörlerden biridir.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.4. Brand ↔ Price

# %%
order = (df.groupby("brand")["price_usd"].mean().sort_values(ascending=False).index)

sns.boxplot(data=df, x="brand", y="price_usd", order=order)

plt.title("Markalara Göre Araç Fiyatı Dağılımı")
plt.xlabel("Marka")
plt.ylabel("Araç Fiyatı (USD)")

plt.xticks(rotation=45)

plt.show()

# %%
brand_price = (df.groupby("brand")["price_usd"].mean().sort_values(ascending=False))

brand_price
# Out:
# brand
# Lucid           192516.878333
# Porsche         157050.798571
# Mercedes        128717.874271
# BMW              98062.344067
# Audi             93875.340130
# Tesla            93522.975645
# Rivian           89973.977568
# Polestar         89828.097778
# Fisker           88699.359200
# NIO              84526.814348
# Xiaomi           78894.801250
# Volvo            78206.630000
# Volkswagen       67915.328763
# Kia              65835.655301
# Toyota           65738.328049
# Ford             65199.069070
# Hyundai          60454.971053
# BYD              60084.840957
# GM/Chevrolet     57247.111888
# Honda            55985.645000
# Name: price_usd, dtype: float64

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Boxplot, araç fiyatlarının markalara göre belirgin şekilde farklılaştığını göstermektedir. Bazı markalar daha yüksek fiyat segmentinde konumlanırken, bazı markalar daha uygun fiyatlı modeller sunmaktadır.</li>
#     <li>Ortalama fiyatlara göre <strong>Lucid</strong>, <strong>Porsche</strong> ve <strong>Mercedes</strong> en yüksek fiyat seviyesine sahip markalar olarak öne çıkmaktadır. Buna karşılık <strong>Honda</strong>, <strong>GM/Chevrolet</strong>, <strong>BYD</strong> ve <strong>Hyundai</strong> daha düşük ortalama fiyatlara sahiptir.</li>
#     <li>Özellikle Tesla, Mercedes, Porsche ve Lucid markalarında fiyat dağılımının geniş olduğu görülmektedir. Bu durum, aynı marka içerisinde farklı donanım seviyeleri ve performans özelliklerine sahip modeller bulunduğunu göstermektedir.</li>
#     <li>Sonuç olarak marka, araç fiyatını etkileyen önemli faktörlerden biridir. Aynı teknik özelliklere sahip araçlar bile marka konumlandırması ve ürün stratejisi nedeniyle farklı fiyat seviyelerinde yer alabilmektedir.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.5. Market Segment ↔ Price

# %%
sns.boxplot(data=df, x="market_segment", y="price_usd")

plt.title("Pazar Segmentlerine Göre Araç Fiyatı Dağılımı")
plt.xlabel("Pazar Segmenti")
plt.ylabel("Araç Fiyatı (USD)")

plt.show()

# %%
segment_price = (df.groupby("market_segment")["price_usd"].mean().sort_values(ascending=False))

segment_price
# Out:
# market_segment
# Luxury       127339.967960
# Premium       81102.328357
# Mid-range     50688.845779
# Budget        29320.750861
# Name: price_usd, dtype: float64

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Boxplot, araç fiyatlarının pazar segmentlerine göre belirgin şekilde ayrıştığını göstermektedir. Segment yükseldikçe araç fiyatlarının da sistematik olarak arttığı görülmektedir.</li>
#     <li>Ortalama fiyatlara göre <strong>luxury</strong> segmenti en yüksek fiyat seviyesine sahipken, onu <strong>premium</strong>, <strong>mid-range</strong> ve <strong>budget</strong> segmentleri takip etmektedir.</li>
#     <li>Luxury segmentinde fiyat dağılımı diğer segmentlere göre daha geniştir. Bu durum, lüks segment içerisinde farklı donanım ve performans seviyelerine sahip araçların bulunduğunu göstermektedir.</li>
#     <li>Sonuç olarak, pazar segmenti araç fiyatını belirleyen temel faktörlerden biridir. Veri setindeki segment sınıflandırmasının fiyat seviyeleriyle tutarlı olduğu görülmektedir.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.6. Brand ↔ Annual Sales Units

# %%
brand_sales = (df.groupby("brand")["annual_sales_units"].mean().sort_values(ascending=False))

brand_sales
# Out:
# brand
# Volkswagen      248384.829897
# Tesla           233777.608295
# BYD             178980.911348
# Hyundai         100151.611842
# Kia             100073.066265
# Mercedes         51904.750000
# BMW              49634.326667
# Audi             49494.792208
# Ford             46956.038760
# Xiaomi           20122.125000
# Lucid            19135.333333
# NIO              17440.304348
# Porsche          16164.071429
# GM/Chevrolet     16028.181818
# Fisker           15662.160000
# Rivian           15632.297297
# Volvo            15144.416667
# Toyota           14717.341463
# Polestar          9872.444444
# Honda             8816.500000
# Name: annual_sales_units, dtype: float64

# %%
sns.barplot(data=df, x="brand", y="annual_sales_units", estimator="mean", errorbar=None, order=brand_sales.index)

plt.title("Markalara Göre Ortalama Yıllık Satış")
plt.xlabel("Marka")
plt.ylabel("Ortalama Yıllık Satış Adedi")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Markalar arasında ortalama yıllık satış adetleri açısından belirgin farklılıklar bulunmaktadır. Satışların birkaç marka üzerinde yoğunlaştığı görülmektedir.</li>
#     <li><strong>Volkswagen</strong>, <strong>Tesla</strong> ve <strong>BYD</strong> en yüksek ortalama satış adetlerine sahip markalar olarak öne çıkmaktadır. Bu durum, söz konusu markaların veri setinde daha geniş bir müşteri kitlesine ulaştığını göstermektedir.</li>
#     <li>Buna karşılık <strong>Honda</strong>, <strong>Polestar</strong>, <strong>Toyota</strong> ve <strong>Volvo</strong> daha düşük ortalama satış değerlerine sahiptir.</li>
#     <li>Fiyat analizleri ile birlikte değerlendirildiğinde, yüksek fiyatlı markaların her zaman en yüksek satış rakamlarına ulaşmadığı görülmektedir. Örneğin <strong>Lucid</strong> en yüksek ortalama fiyat seviyesine sahip olmasına rağmen satış adedi oldukça düşüktür. Buna karşılık <strong>Volkswagen</strong> ve <strong>Tesla</strong> daha geniş pazarlara hitap ederek yüksek satış hacimlerine ulaşmaktadır.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.7. Market Segment ↔ Annual Sales Units

# %%
segment_sales = (df.groupby("market_segment")["annual_sales_units"].mean().sort_values(ascending=False))

segment_sales
# Out:
# market_segment
# Budget       154658.324503
# Luxury       133264.824242
# Mid-range    130030.981308
# Premium      121499.717697
# Name: annual_sales_units, dtype: float64

# %%
sns.barplot(data=df, x="market_segment", y="annual_sales_units", estimator="mean", errorbar=None, order=segment_sales.index)

plt.title("Pazar Segmentlerine Göre Ortalama Yıllık Satış")
plt.xlabel("Pazar Segmenti")
plt.ylabel("Ortalama Yıllık Satış Adedi")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analiz</h3>
#   <ul>
#     <li>Pazar segmentleri arasında ortalama yıllık satış adetleri incelendiğinde, <strong>budget</strong> segmentinin en yüksek ortalama satış değerine sahip olduğu görülmektedir.</li>
#     <li>Ancak segmentler arasındaki satış farkları fiyat analizindeki kadar belirgin değildir. <strong>luxury</strong>, <strong>mid-range</strong> ve <strong>premium</strong> segmentlerinin ortalama satış değerleri birbirine oldukça yakındır.</li>
#     <li>Bu sonuç, veri setinde satış performansının yalnızca pazar segmentiyle açıklanamayacağını göstermektedir. Marka, model çeşitliliği, performans özellikleri ve diğer faktörler de satış hacmini etkiliyor olabilir.</li>
#     <li>Fiyat analizleri ile birlikte değerlendirildiğinde, daha düşük fiyatlı segmentlerin her zaman açık ara daha fazla satış yapmadığı görülmektedir. Bu durum, segment ile satış arasındaki ilişkinin fiyat kadar belirgin olmadığını göstermektedir.</li>
#   </ul>
# </div>

# %% [markdown]
# # 6. İş İçgörüleri

# %% [markdown]
# Bu keşifsel veri analizi sonucunda elektrikli araç veri seti üzerinde aşağıdaki temel iş içgörüleri elde edilmiştir:
#
# - **Batarya kapasitesi** ile **araç menzili** arasında **çok güçlü pozitif bir ilişki (r = 0.978)** bulunmaktadır. Bu sonuç, araç menzilini belirleyen en önemli teknik faktörlerden birinin batarya kapasitesi olduğunu göstermektedir.
#
# - **Motor gücü**, araç fiyatı üzerinde **batarya kapasitesinden daha belirgin bir etkiye** sahiptir. **Araç fiyatı ile motor gücü arasında güçlü bir ilişki (r = 0.765)** bulunurken, **batarya kapasitesi ile fiyat arasındaki ilişki oldukça zayıf (r = 0.164)** kalmıştır.
#
# - **Daha uzun menzilli araçlar**, kullanıcılar tarafından **daha yüksek müşteri puanı alma eğilimindedir (r = 0.668)**. Bu durum, sürüş menzilinin müşteri memnuniyetini etkileyen önemli özelliklerden biri olduğunu göstermektedir.
#
# - **Lucid**, **Porsche** ve **Mercedes**, en yüksek ortalama fiyat seviyesine sahip markalar olarak öne çıkmaktadır. Buna karşılık **Volkswagen**, **Tesla** ve **BYD**, en yüksek ortalama satış hacmine sahip markalar arasında yer almaktadır. Bu bulgu, **yüksek fiyatın her zaman yüksek satış anlamına gelmediğini** göstermektedir.
#
# - **Luxury** segmenti en yüksek ortalama araç fiyatına sahip olmasına rağmen, **budget** segmenti en yüksek ortalama satış değerini göstermektedir. Bu durum, fiyat seviyesinin tek başına satış performansını açıklamak için yeterli olmadığını ortaya koymaktadır.
#
# - Sayısal değişken analizleri, veri setindeki yüksek fiyat, yüksek motor gücü ve yüksek müşteri puanı gibi uç değerlerin büyük ölçüde **premium ve yüksek performanslı araçlardan** kaynaklandığını göstermektedir. Bu nedenle bu gözlemler veri hatası olarak değerlendirilmemiştir.
#
# - Genel olarak değerlendirildiğinde, teknik özellikler, marka konumlandırması ve pazar segmenti, araçların fiyatı, satış performansı ve müşteri memnuniyeti üzerinde birlikte etkili olmaktadır. Elektrikli araç pazarını değerlendirmek için bu faktörlerin birlikte ele alınması gerekmektedir.

# %% [markdown]
# # 7. Sonuç

# %% [markdown]
# Bu çalışma kapsamında elektrikli araç veri seti üzerinde kapsamlı bir keşifsel veri analizi gerçekleştirilmiştir. Veri kalitesi değerlendirilmiş, sayısal ve kategorik değişkenler incelenmiş, değişkenler arasındaki ilişkiler analiz edilmiş ve iş açısından anlamlı çıkarımlar elde edilmiştir. Elde edilen bulgular, araç fiyatı, menzil, performans ve satışlar arasındaki ilişkileri ortaya koyarken, veri setinin sonraki aşamalarda gerçekleştirilecek tahmine dayalı modelleme veya iş zekâsı uygulamaları için uygun bir temel oluşturduğunu göstermektedir.
