# %% [markdown]
# # 1. About the Dataset
#
# ![1.png](attachment:de315075-5956-4d9a-8262-7d0710718b8a.png)
#
# This dataset contains technical and commercial performance data for electric vehicle (EV) models produced between 2020 and 2026. The dataset includes a total of 2000 observations and 24 columns, where each row represents a specific brand's model for a given year and variant (base, long range, premium, performance, standard).
#
# **The brands included in the dataset are as follows:**
#
# - **Germany:** Audi, BMW, Mercedes, Porsche, Volkswagen
# - **USA:** Fisker, Ford, GM/Chevrolet, Lucid, Rivian, Tesla
# - **Japan:** Honda, Toyota
# - **South Korea:** Hyundai, Kia
# - **China:** BYD, NIO, Xiaomi
# - **Sweden:** Polestar, Volvo
#
# **The meanings of the 24 columns in the dataset are as follows:**
#
# <table style='text-align: left; margin-left: 0;'>
#   <tr>
#     <th>Column Name</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td><strong>brand</strong></td>
#     <td>Vehicle brand</td>
#   </tr>
#   <tr>
#     <td><strong>model</strong></td>
#     <td>Vehicle model name</td>
#   </tr>
#   <tr>
#     <td><strong>year</strong></td>
#     <td>Model year</td>
#   </tr>
#   <tr>
#     <td><strong>variant</strong></td>
#     <td>Model variant (base, standard, long range, premium, performance)</td>
#   </tr>
#   <tr>
#     <td><strong>price_usd</strong></td>
#     <td>Vehicle sale price (USD)</td>
#   </tr>
#   <tr>
#     <td><strong>battery_capacity_kwh</strong></td>
#     <td>Battery capacity (kWh)</td>
#   </tr>
#   <tr>
#     <td><strong>range_miles</strong></td>
#     <td>Distance on a full charge (miles)</td>
#   </tr>
#   <tr>
#     <td><strong>charging_speed_kw</strong></td>
#     <td>Maximum fast-charging power (kW)</td>
#   </tr>
#   <tr>
#     <td><strong>acceleration_0_60_mph</strong></td>
#     <td>0-60 mph acceleration time (seconds)</td>
#   </tr>
#   <tr>
#     <td><strong>top_speed_mph</strong></td>
#     <td>Top speed (mph)</td>
#   </tr>
#   <tr>
#     <td><strong>horsepower</strong></td>
#     <td>Engine power (horsepower, hp)</td>
#   </tr>
#   <tr>
#     <td><strong>torque_nm</strong></td>
#     <td>Engine torque (Nm)</td>
#   </tr>
#   <tr>
#     <td><strong>drive_type</strong></td>
#     <td>Drive type (FWD, RWD, AWD)</td>
#   </tr>
#   <tr>
#     <td><strong>seating_capacity</strong></td>
#     <td>Seating capacity</td>
#   </tr>
#   <tr>
#     <td><strong>body_type</strong></td>
#     <td>Body type (sedan, SUV, hatchback, coupe, van, truck)</td>
#   </tr>
#   <tr>
#     <td><strong>cargo_volume_cubic_ft</strong></td>
#     <td>Cargo/load volume (cubic feet)</td>
#   </tr>
#   <tr>
#     <td><strong>weight_kg</strong></td>
#     <td>Vehicle weight (kg)</td>
#   </tr>
#   <tr>
#     <td><strong>safety_rating</strong></td>
#     <td>Safety rating (1-5)</td>
#   </tr>
#   <tr>
#     <td><strong>autopilot_level</strong></td>
#     <td>Autonomous driving level (0-3)</td>
#   </tr>
#   <tr>
#     <td><strong>country_of_origin</strong></td>
#     <td>Brand's country of origin</td>
#   </tr>
#   <tr>
#     <td><strong>market_segment</strong></td>
#     <td>Market segment (budget, mid-range, premium, luxury)</td>
#   </tr>
#   <tr>
#     <td><strong>annual_sales_units</strong></td>
#     <td>Annual sales units</td>
#   </tr>
#   <tr>
#     <td><strong>customer_rating</strong></td>
#     <td>Customer satisfaction rating (1-5)</td>
#   </tr>
#   <tr>
#     <td><strong>warranty_years</strong></td>
#     <td>Warranty period (years)</td>
#   </tr>
# </table>

# %% [markdown]
# # 2. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 11
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 120)
warnings.filterwarnings('ignore')

# %% [markdown]
# # 3. Loading the Dataset

# %%
df = pd.read_csv('../data/electric_vehicle.csv')

df
# Out:
#              brand           model  year      variant  price_usd  battery_capacity_kwh  range_miles  \
# 0       Volkswagen        ID. Buzz  2023  Performance  104880.80                 118.7        400.0
# 1           Toyota  bZ Compact SUV  2022      Premium   48217.41                  58.8        219.0
# 2     GM/Chevrolet         Bolt EV  2024      Premium   49651.12                  58.2        225.0
# 3              Kia     Sportage EV  2024   Long Range   38131.56                 102.5        349.0
# 4            Tesla         Model 3  2022   Long Range  144079.87                  93.9        314.0
# ...            ...             ...   ...          ...        ...                   ...          ...
# 1995           BMW              i3  2023   Long Range  122665.71                 102.1        360.0
# 1996        Toyota            bZ4X  2024  Performance   66816.55                 110.6        367.0
# ...

# %% [markdown]
# # 4. Overview of the Dataset

# %%
df.head()
# Out:
#           brand           model  year      variant  price_usd  battery_capacity_kwh  range_miles  charging_speed_kw  \
# 0    Volkswagen        ID. Buzz  2023  Performance  104880.80                 118.7        400.0              234.5
# 1        Toyota  bZ Compact SUV  2022      Premium   48217.41                  58.8        219.0              148.1
# 2  GM/Chevrolet         Bolt EV  2024      Premium   49651.12                  58.2        225.0              104.9
# 3           Kia     Sportage EV  2024   Long Range   38131.56                 102.5        349.0               66.5
# 4         Tesla         Model 3  2022   Long Range  144079.87                  93.9        314.0              298.5
#
#    acceleration_0_60_mph  top_speed_mph  horsepower  torque_nm drive_type  seating_capacity body_type  \
# 0                   3.04          195.0      1000.0      895.0        AWD                 7     Truck
# ...

# %%
df.tail()
# Out:
#        brand    model  year      variant  price_usd  battery_capacity_kwh  range_miles  charging_speed_kw  \
# 1995     BMW       i3  2023   Long Range  122665.71                 102.1        360.0               92.0
# 1996  Toyota     bZ4X  2024  Performance   66816.55                 110.6        367.0              236.3
# 1997   Tesla  Model 3  2025   Long Range   49281.26                  90.6        325.0              325.6
# 1998   Tesla  Model X  2026      Premium  139665.73                  70.7        248.0              330.7
# 1999     BYD      Qin  2025      Premium   47547.88                  67.4        246.0               67.2
#
#       acceleration_0_60_mph  top_speed_mph  horsepower  torque_nm drive_type  seating_capacity  body_type  \
# 1995                   4.21          190.0      1000.0      935.0        FWD                 5  Hatchback
# 1996                   4.25          181.0       783.0      733.0        AWD                 5  Hatchback
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   brand                  2000 non-null   object
#  1   model                  2000 non-null   object
#  2   year                   2000 non-null   int64
#  3   variant                2000 non-null   object
#  4   price_usd              2000 non-null   float64
#  5   battery_capacity_kwh   2000 non-null   float64
#  6   range_miles            2000 non-null   float64
#  7   charging_speed_kw      2000 non-null   float64
#  8   acceleration_0_60_mph  2000 non-null   float64
#  9   top_speed_mph          2000 non-null   float64
#  10  horsepower             2000 non-null   float64
#  11  torque_nm              2000 non-null   float64
#  12  drive_type             2000 non-null   object
#  13  seating_capacity       2000 non-null   int64
# ...

# %%
df.shape
# Out:
# (2000, 24)

# %%
df.columns
# Out:
# Index(['brand', 'model', 'year', 'variant', 'price_usd', 'battery_capacity_kwh', 'range_miles', 'charging_speed_kw',
#        'acceleration_0_60_mph', 'top_speed_mph', 'horsepower', 'torque_nm', 'drive_type', 'seating_capacity',
#        'body_type', 'cargo_volume_cubic_ft', 'weight_kg', 'safety_rating', 'autopilot_level', 'country_of_origin',
#        'market_segment', 'annual_sales_units', 'customer_rating', 'warranty_years'],
#       dtype='object')

# %%
df.dtypes
# Out:
# brand                     object
# model                     object
# year                       int64
# variant                   object
# price_usd                float64
# battery_capacity_kwh     float64
# range_miles              float64
# charging_speed_kw        float64
# acceleration_0_60_mph    float64
# top_speed_mph            float64
# horsepower               float64
# torque_nm                float64
# drive_type                object
# seating_capacity           int64
# body_type                 object
# cargo_volume_cubic_ft    float64
# weight_kg                float64
# safety_rating              int64
# autopilot_level            int64
# country_of_origin         object
# market_segment            object
# annual_sales_units         int64
# customer_rating          float64
# warranty_years             int64
# dtype: object

# %%
df.describe()
# Out:
#               year      price_usd  battery_capacity_kwh  range_miles  charging_speed_kw  acceleration_0_60_mph  \
# count  2000.000000    2000.000000           2000.000000  2000.000000        2000.000000            2000.000000
# mean   2024.028500   78873.907150             74.662800   261.825500         155.206300               5.630635
# std       1.410561   35296.621782             20.082879    71.028238          80.982301               1.417733
# min    2020.000000   16394.330000             40.000000   150.000000          50.000000               2.500000
# 25%    2023.000000   52325.920000             58.475000   204.000000          90.975000               4.620000
# 50%    2024.000000   73013.015000             75.100000   261.000000         132.100000               5.670000
# 75%    2025.000000   99780.157500             87.550000   310.000000         217.300000               6.770000
# ...

# %%
df.isnull().sum()
# Out:
# brand                    0
# model                    0
# year                     0
# variant                  0
# price_usd                0
# battery_capacity_kwh     0
# range_miles              0
# charging_speed_kw        0
# acceleration_0_60_mph    0
# top_speed_mph            0
# horsepower               0
# torque_nm                0
# drive_type               0
# seating_capacity         0
# body_type                0
# cargo_volume_cubic_ft    0
# weight_kg                0
# safety_rating            0
# autopilot_level          0
# country_of_origin        0
# market_segment           0
# annual_sales_units       0
# customer_rating          0
# warranty_years           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
numerical_columns = df.select_dtypes(include=['number']).columns

numerical_columns
# Out:
# Index(['year', 'price_usd', 'battery_capacity_kwh', 'range_miles', 'charging_speed_kw', 'acceleration_0_60_mph',
#        'top_speed_mph', 'horsepower', 'torque_nm', 'seating_capacity', 'cargo_volume_cubic_ft', 'weight_kg',
#        'safety_rating', 'autopilot_level', 'annual_sales_units', 'customer_rating', 'warranty_years'],
#       dtype='object')

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

categorical_columns
# Out:
# Index(['brand', 'model', 'variant', 'drive_type', 'body_type', 'country_of_origin', 'market_segment'], dtype='object')

# %% [markdown]
# # 5. Exploratory Data Analysis (EDA)
# ## 5.1. Numerical Variable Analysis
# ### 5.1.1. Price

# %%
plt.hist(df["price_usd"], bins=30)

plt.title("Distribution of Vehicle Prices")
plt.xlabel("Price (USD)")
plt.ylabel("Frequency")

plt.show()

# %%
plt.boxplot(df["price_usd"])

plt.title("Box Plot of Vehicle Prices")
plt.ylabel("Price (USD)")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>Vehicle prices are concentrated mainly in the <strong>50,000-100,000 USD</strong> range.</li>
#     <li>The histogram and box plot confirm the mean (<strong>≈78,874 USD</strong>) and median (<strong>≈73,013 USD</strong>) values from the <code>describe()</code> output. The mean being higher than the median indicates that the distribution is <strong>right-skewed</strong>.</li>
#     <li>The longer upper whisker and higher concentration of observations on the upper side of the box plot further support the right-skewed distribution.</li>
#     <li>Vehicles priced above <strong>200,000 USD</strong> are few in number and appear as potential outliers in the box plot. However, considering the luxury and high-performance models in the EV market, these observations can be regarded as a natural part of the dataset.</li>
#     <li>Overall, the price_usd variable shows a balanced and consistent distribution, and there is no clear issue requiring intervention during data cleaning.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.2. Battery Capacity

# %%
plt.hist(df["battery_capacity_kwh"], bins=20)

plt.title("Distribution of Battery Capacity")
plt.xlabel("Battery Capacity (kWh)")
plt.ylabel("Frequency")

plt.show()

# %%
plt.boxplot(df["battery_capacity_kwh"])

plt.title("Box Plot of Battery Capacity")
plt.ylabel("Battery Capacity (kWh)")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>Battery capacities range from approximately <strong>40-120 kWh</strong>. These values represent a realistic and expected range for today's electric vehicles.</li>
#     <li>The histogram and box plot confirm that most battery capacities are concentrated in the <strong>60-90 kWh</strong> range.</li>
#     <li>The mean (<strong>≈74.66 kWh</strong>) and median (<strong>≈75 kWh</strong>) values from the <code>describe()</code> output being quite close to each other supports the finding that the distribution does not show a pronounced right or left skew.</li>
#     <li>No statistically potential outliers are present in the box plot, and there is no clear finding pointing to data entry errors or unusual observations.</li>
#     <li>Overall, the battery_capacity_kwh variable shows a balanced, consistent, and reliable distribution in terms of data quality.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.3. Range

# %%
sns.histplot(data=df, x='range_miles', bins=20)

plt.title("Distribution of Vehicle Range")
plt.xlabel("Range (Miles)")
plt.ylabel("Frequency")

plt.show()

# %%
plt.boxplot(df["range_miles"])

plt.title("Box Plot of Vehicle Range")
plt.ylabel("Range (Miles)")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>Vehicle ranges are distributed within approximately <strong>150-450 miles</strong>. These values represent a realistic range consistent with today's electric vehicle market.</li>
#     <li>The histogram and box plot confirm that most vehicle ranges are concentrated in the <strong>240-300 mile</strong> range. The median value of approximately <strong>260 miles</strong> in the <code>describe()</code> output also supports this finding.</li>
#     <li>The distribution shows a <strong>slightly right-skewed</strong> structure. The number of vehicles above 350 miles gradually decreases, and vehicles above 400 miles are more limited in the dataset.</li>
#     <li>No statistically potential outliers are present in the box plot, and the values in the approximate <strong>150-450 mile</strong> range do not point to data entry errors.</li>
#     <li>Overall, the range_miles variable shows a balanced and consistent distribution, and there is no clear issue requiring intervention during data cleaning.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.4. Horsepower

# %%
sns.histplot(data=df, x="horsepower", bins=20)

plt.axvline(df["horsepower"].mean(), color="red", linestyle="--", label="Mean")
plt.axvline(df["horsepower"].median(), color="green", linestyle="-", label="Median")

plt.title("Distribution of Horsepower")
plt.xlabel("Horsepower (HP)")
plt.ylabel("Frequency")

plt.legend()

plt.show()

# %%
df["horsepower"].describe()
# Out:
# count    2000.000000
# mean      665.744000
# std       267.124838
# min       150.000000
# 25%       442.750000
# 50%       683.000000
# 75%       939.250000
# max      1000.000000
# Name: horsepower, dtype: float64

# %%
df["horsepower"].value_counts().head(10)
# Out:
# horsepower
# 1000.0    422
# 150.0      20
# 376.0       6
# 378.0       6
# 752.0       6
# 493.0       6
# 335.0       6
# 505.0       6
# 586.0       6
# 716.0       6
# Name: count, dtype: int64

# %%
plt.boxplot(df["horsepower"])

plt.title("Box Plot of Horsepower")
plt.ylabel("Horsepower (HP)")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>Horsepower values are distributed within approximately <strong>150-1000 HP</strong>.</li>
#     <li>The histogram and box plot confirm the mean (<strong>≈665.74 HP</strong>) and median (<strong>683 HP</strong>) values from the <code>describe()</code> output. The median being slightly higher than the mean indicates that the distribution is <strong>slightly left-skewed</strong>.</li>
#     <li>No statistically potential outliers are present in the box plot. This shows that the concentration at 1000 HP is not classified as an outlier according to the IQR method.</li>
#     <li>The <code>value_counts()</code> analysis shows that <strong>422 vehicles</strong> have a horsepower value of exactly <strong>1000 HP</strong>. This concentration may result from the synthetic structure of the dataset or from an upper limit (<em>ceiling effect</em>) applied during data generation.</li>
#     <li>Overall, the horsepower variable does not contain a clear issue requiring intervention in terms of data cleaning. However, the concentration at the 1000 HP level should be kept in mind when interpreting subsequent analyses.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.5. Annual Sales Units

# %%
sns.histplot(data=df, x="annual_sales_units", bins=20)

plt.axvline(df["annual_sales_units"].mean(), color="red", linestyle="--", linewidth=2, label="Mean")
plt.axvline(df["annual_sales_units"].median(), color="green", linewidth=2, label="Median")

plt.title("Distribution of Annual Sales Units")
plt.xlabel("Annual Sales Units")
plt.ylabel("Frequency")

plt.legend()

plt.show()

# %%
sns.boxplot(y=df["annual_sales_units"])

plt.title("Box Plot of Annual Sales Units")
plt.ylabel("Annual Sales Units")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>Annual sales units are distributed within approximately <strong>0-500,000</strong>. Most vehicles are concentrated below <strong>200,000</strong> units.</li>
#     <li>Considering the histogram and box plot together, the median is seen to be lower than the mean. This shows that the distribution is <strong>right-skewed</strong>, as high sales values pull the mean upward.</li>
#     <li>The box plot shows statistically potential outliers in the approximate <strong>440,000-500,000</strong> range. Rather than indicating data entry errors, these values may represent models with exceptional sales success in the market.</li>
#     <li>The histogram shows that the number of vehicles with high sales units is limited, while vehicles with low and medium sales levels are more prevalent in the dataset.</li>
#     <li>Overall, the annual_sales_units variable does not contain a clear issue requiring intervention in terms of data cleaning. However, high sales values should be kept in mind when interpreting subsequent analyses, as they can affect the mean.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.1.6. Customer Rating

# %%
sns.histplot(data=df, x="customer_rating", bins=20)

plt.axvline(df["customer_rating"].mean(), color="red", linestyle="--", linewidth=2, label="Mean")
plt.axvline(df["customer_rating"].median(), color="green", linewidth=2, label="Median")

plt.title("Distribution of Customer Rating")
plt.xlabel("Customer Rating")
plt.ylabel("Frequency")

plt.legend()

plt.show()

# %%
sns.boxplot(y=df["customer_rating"])

plt.title("Box Plot of Customer Rating")
plt.ylabel("Customer Rating")

plt.show()

# %%
df["customer_rating"].describe()
# Out:
# count    2000.000000
# mean        3.572045
# std         0.270398
# min         3.000000
# 25%         3.380000
# 50%         3.560000
# 75%         3.750000
# max         4.510000
# Name: customer_rating, dtype: float64

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>Customer ratings are distributed within the <strong>3.0-4.5</strong> range. Most values are concentrated in the <strong>3.4-3.8</strong> range.</li>
#     <li>The histogram and box plot confirm the mean (<strong>≈3.57</strong>) and median (<strong>3.56</strong>) values from the <code>describe()</code> output. The mean and median being quite close to each other shows that the distribution is generally balanced.</li>
#     <li>The distribution shows a slightly <strong>right-skewed</strong> structure. The number of customer ratings above 4.0 gradually decreases, and values of 4.3 and above are more limited.</li>
#     <li>The box plot shows statistically potential outliers in the approximate <strong>4.3-4.5</strong> range. However, since these values may represent models with quite high customer satisfaction, they should not be regarded as data errors.</li>
#     <li>Overall, the customer_rating variable shows a consistent distribution, and there is no clear issue requiring intervention during data cleaning.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.2. Categorical Variable Analysis
# ### 5.2.1. Brand

# %%
df["brand"].value_counts()
# Out:
# brand
# Tesla           434
# BYD             282
# Volkswagen      194
# Kia             166
# Hyundai         152
# BMW             150
# GM/Chevrolet    143
# Ford            129
# Mercedes         96
# Audi             77
# Toyota           41
# Rivian           37
# Fisker           25
# NIO              23
# Porsche          14
# Volvo            12
# Polestar          9
# Xiaomi            8
# Lucid             6
# Honda             2
# Name: count, dtype: int64

# %%
sns.countplot(data=df, y="brand", order=df["brand"].value_counts().index)

plt.title("Number of Vehicles by Brand")
plt.xlabel("Number of Vehicles")
plt.ylabel("Brand")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>There are a total of <strong>20 different vehicle brands</strong> in the dataset. The brand distribution is not balanced, as certain brands are represented more heavily in the dataset.</li>
#     <li><strong>Tesla</strong> is the most represented brand in the dataset with <strong>434</strong> vehicles, followed by <strong>BYD (282)</strong> and <strong>Volkswagen (194)</strong>.</li>
#     <li>Looking at the chart, most vehicles are concentrated among the first few brands, while brands such as Lucid, Xiaomi, Polestar, and Honda are represented by quite a limited number in the dataset.</li>
#     <li>This distribution does not indicate that the dataset directly represents real market shares. Some brands having more observations may stem from the distribution used during data generation.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.2.2. Body Type

# %%
df["body_type"].value_counts()
# Out:
# body_type
# Truck        427
# SUV          364
# Hatchback    324
# Coupe        303
# Sedan        301
# Van          281
# Name: count, dtype: int64

# %%
sns.countplot(data=df, y="body_type", order=df["body_type"].value_counts().index)

plt.title("Number of Vehicles by Body Type")
plt.xlabel("Number of Vehicles")
plt.ylabel("Body Type")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>There are a total of <strong>6 different body types</strong> in the dataset. The body types generally show a balanced distribution.</li>
#     <li><strong>Truck (427)</strong> is the most represented body type in the dataset, followed by <strong>SUV (364)</strong> and <strong>hatchback (324)</strong>.</li>
#     <li>The coupe, sedan, and van categories also contain a similar number of observations, and there is no body type that is clearly underrepresented in the dataset.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.2.3. Drive Type

# %%
df["drive_type"].value_counts()
# Out:
# drive_type
# AWD    754
# RWD    678
# FWD    568
# Name: count, dtype: int64

# %%
sns.countplot(data=df, y="drive_type", order=df["drive_type"].value_counts().index)

plt.title("Number of Vehicles by Drive Type")
plt.xlabel("Number of Vehicles")
plt.ylabel("Drive Type")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>There are a total of <strong>3 different drive types</strong> in the dataset. The drive types generally show a balanced distribution.</li>
#     <li><strong>AWD (754)</strong> is the most represented drive type in the dataset, followed by <strong>RWD (678)</strong> and <strong>FWD (568)</strong>.</li>
#     <li>Since all three drive types contain a high number of observations, this allows reliable comparisons to be made between drive types in subsequent analyses.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.2.4. Market Segment

# %%
df["market_segment"].value_counts()
# Out:
# market_segment
# Premium      712
# Mid-range    642
# Luxury       495
# Budget       151
# Name: count, dtype: int64

# %%
sns.countplot(data=df, y="market_segment", order=df["market_segment"].value_counts().index)

plt.title("Number of Vehicles by Market Segment")
plt.xlabel("Number of Vehicles")
plt.ylabel("Market Segment")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>There are a total of <strong>4 different market segments</strong> in the dataset. Most vehicles are concentrated in the premium and mid-range segments.</li>
#     <li>The <strong>Premium (712)</strong> segment is the most represented category in the dataset, followed by the <strong>mid-range (642)</strong> and <strong>luxury (495)</strong> segments.</li>
#     <li>The <strong>Budget (151)</strong> segment contains fewer vehicles compared to the other segments. This shows that the dataset focuses more on mid- and upper-segment electric vehicles.</li>
#     <li>The market segment variable will be used in subsequent analyses together with performance indicators such as price, range, sales units, and customer rating to examine differences between segments.</li>
#   </ul>
# </div>

# %% [markdown]
# ## 5.3. Analysis of Relationships Between Variables

# %%
corr = df.select_dtypes(include="number").corr()

sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")

plt.title("Correlation Matrix of Numerical Variables")

plt.show()

# %% [markdown]
# ### 5.3.1. Range ↔ Battery Capacity

# %%
sns.regplot(data=df, x="battery_capacity_kwh", y="range_miles", scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})

plt.title("Relationship Between Battery Capacity and Range")
plt.xlabel("Battery Capacity (kWh)")
plt.ylabel("Range (Miles)")

plt.show()

# %%
df["battery_capacity_kwh"].corr(df["range_miles"])
# Out:
# np.float64(0.9778585581959761)

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>The scatter plot shows a very strong linear relationship between battery capacity and vehicle range. The dense clustering of points around the regression line clearly supports this relationship.</li>
#     <li>The calculated Pearson correlation coefficient is <strong>r = 0.978</strong>, indicating a <strong>very strong positive</strong> relationship between the two variables.</li>
#     <li>As battery capacity increases, vehicle range also increases significantly. This is consistent with the technical expectation that larger battery packs provide longer driving distances in electric vehicles.</li>
#     <li>This analysis shows that battery capacity is one of the most important variables explaining vehicle range. It is also one of the strongest relationships observed in the heatmap analysis.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.2. Price ↔ Horsepower

# %%
sns.regplot(data=df, x="horsepower", y="price_usd", scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})

plt.title("Relationship Between Engine Power and Vehicle Price")
plt.xlabel("Engine Power (HP)")
plt.ylabel("Vehicle Price (USD)")

plt.show()

# %%
df["horsepower"].corr(df["price_usd"])
# Out:
# np.float64(0.7647243074137059)

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>The scatter plot shows a clear positive linear relationship between engine power and vehicle price. As engine power increases, vehicle price also generally increases.</li>
#     <li>The calculated Pearson correlation coefficient is <strong>r = 0.765</strong>, indicating a <strong>strong positive</strong> relationship between the two variables.</li>
#     <li>A dense cluster of data is particularly visible at <strong>1000 HP</strong> in the chart. This reflects a ceiling effect resulting from the maximum engine power limit in the dataset.</li>
#     <li>Vehicles with the same engine power being found at different price levels shows that vehicle price cannot be explained by engine power alone. Other factors such as brand, equipment level, technology, battery features, and market segment also play an important role in price.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.3. Range ↔ Customer Rating

# %%
sns.regplot(data=df, x="range_miles", y="customer_rating", scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})

plt.title("Relationship Between Vehicle Range and Customer Rating")
plt.xlabel("Range (Miles)")
plt.ylabel("Customer Rating")

plt.show()

# %%
df["range_miles"].corr(df["customer_rating"])
# Out:
# np.float64(0.6681371738521219)

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>The scatter plot shows a positive relationship between vehicle range and customer rating. As vehicle range increases, customer ratings also tend to generally increase.</li>
#     <li>The calculated Pearson correlation coefficient is <strong>r = 0.668</strong>, indicating a <strong>moderately strong positive</strong> relationship between the two variables.</li>
#     <li>The chart shows that vehicles with the same range value receive different customer ratings. This indicates that customer satisfaction cannot be explained by vehicle range alone; other factors such as brand, price, performance, equipment level, and user experience are also influential.</li>
#     <li>Nevertheless, the positive relationship obtained shows that long range may be one of the important features that increases customer satisfaction. Range is one of the key factors influencing the purchase decision and user experience, especially for electric vehicle users.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.4. Brand ↔ Price

# %%
order = (df.groupby("brand")["price_usd"].mean().sort_values(ascending=False).index)

sns.boxplot(data=df, x="brand", y="price_usd", order=order)

plt.title("Distribution of Vehicle Price by Brand")
plt.xlabel("Brand")
plt.ylabel("Vehicle Price (USD)")

plt.xticks(rotation=45)

plt.show()

# %%
brand_price = (df.groupby("brand")["price_usd"].mean().sort_values(ascending=False))

brand_price
# Out:
# brand
# Lucid           192516.878333
# Porsche         157050.798571
# Mercedes        128717.874271
# BMW              98062.344067
# Audi             93875.340130
# Tesla            93522.975645
# Rivian           89973.977568
# Polestar         89828.097778
# Fisker           88699.359200
# NIO              84526.814348
# Xiaomi           78894.801250
# Volvo            78206.630000
# Volkswagen       67915.328763
# Kia              65835.655301
# Toyota           65738.328049
# Ford             65199.069070
# Hyundai          60454.971053
# BYD              60084.840957
# GM/Chevrolet     57247.111888
# Honda            55985.645000
# Name: price_usd, dtype: float64

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>The box plot shows that vehicle prices differ significantly by brand. Some brands are positioned in a higher price segment, while others offer more affordable models.</li>
#     <li>By average price, <strong>Lucid</strong>, <strong>Porsche</strong>, and <strong>Mercedes</strong> stand out as the brands with the highest price levels. In contrast, <strong>Honda</strong>, <strong>GM/Chevrolet</strong>, <strong>BYD</strong>, and <strong>Hyundai</strong> have lower average prices.</li>
#     <li>The price distribution is particularly wide for Tesla, Mercedes, Porsche, and Lucid. This shows that these brands offer models with different equipment levels and performance features.</li>
#     <li>In conclusion, brand is one of the important factors influencing vehicle price. Even vehicles with the same technical specifications can be found at different price levels due to brand positioning and product strategy.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.5. Market Segment ↔ Price

# %%
sns.boxplot(data=df, x="market_segment", y="price_usd")

plt.title("Distribution of Vehicle Price by Market Segment")
plt.xlabel("Market Segment")
plt.ylabel("Vehicle Price (USD)")

plt.show()

# %%
segment_price = (df.groupby("market_segment")["price_usd"].mean().sort_values(ascending=False))

segment_price
# Out:
# market_segment
# Luxury       127339.967960
# Premium       81102.328357
# Mid-range     50688.845779
# Budget        29320.750861
# Name: price_usd, dtype: float64

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>The box plot shows that vehicle prices are clearly separated by market segment. As the segment level rises, vehicle prices also increase systematically.</li>
#     <li>By average price, the <strong>luxury</strong> segment has the highest price level, followed by the <strong>premium</strong>, <strong>mid-range</strong>, and <strong>budget</strong> segments.</li>
#     <li>The price distribution in the luxury segment is wider than in the other segments. This shows that the luxury segment includes vehicles with different equipment and performance levels.</li>
#     <li>In conclusion, market segment is one of the key factors determining vehicle price. The segment classification in the dataset appears consistent with price levels.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.6. Brand ↔ Annual Sales Units

# %%
brand_sales = (df.groupby("brand")["annual_sales_units"].mean().sort_values(ascending=False))

brand_sales
# Out:
# brand
# Volkswagen      248384.829897
# Tesla           233777.608295
# BYD             178980.911348
# Hyundai         100151.611842
# Kia             100073.066265
# Mercedes         51904.750000
# BMW              49634.326667
# Audi             49494.792208
# Ford             46956.038760
# Xiaomi           20122.125000
# Lucid            19135.333333
# NIO              17440.304348
# Porsche          16164.071429
# GM/Chevrolet     16028.181818
# Fisker           15662.160000
# Rivian           15632.297297
# Volvo            15144.416667
# Toyota           14717.341463
# Polestar          9872.444444
# Honda             8816.500000
# Name: annual_sales_units, dtype: float64

# %%
sns.barplot(data=df, x="brand", y="annual_sales_units", estimator="mean", errorbar=None, order=brand_sales.index)

plt.title("Average Annual Sales by Brand")
plt.xlabel("Brand")
plt.ylabel("Average Annual Sales Units")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>There are notable differences between brands in terms of average annual sales units. Sales appear to be concentrated among a few brands.</li>
#     <li><strong>Volkswagen</strong>, <strong>Tesla</strong>, and <strong>BYD</strong> stand out as the brands with the highest average sales units. This shows that these brands reach a wider customer base in the dataset.</li>
#     <li>In contrast, <strong>Honda</strong>, <strong>Polestar</strong>, <strong>Toyota</strong>, and <strong>Volvo</strong> have lower average sales values.</li>
#     <li>When evaluated together with the price analyses, it is seen that higher-priced brands do not always achieve the highest sales figures. For example, <strong>Lucid</strong> has the highest average price level but quite low sales units. In contrast, <strong>Volkswagen</strong> and <strong>Tesla</strong> reach wider markets and achieve high sales volumes.</li>
#   </ul>
# </div>

# %% [markdown]
# ### 5.3.7. Market Segment ↔ Annual Sales Units

# %%
segment_sales = (df.groupby("market_segment")["annual_sales_units"].mean().sort_values(ascending=False))

segment_sales
# Out:
# market_segment
# Budget       154658.324503
# Luxury       133264.824242
# Mid-range    130030.981308
# Premium      121499.717697
# Name: annual_sales_units, dtype: float64

# %%
sns.barplot(data=df, x="market_segment", y="annual_sales_units", estimator="mean", errorbar=None, order=segment_sales.index)

plt.title("Average Annual Sales by Market Segment")
plt.xlabel("Market Segment")
plt.ylabel("Average Annual Sales Units")

plt.show()

# %% [markdown]
# <div style='background-color: #e3f2fd; border-left: 5px solid #2196F3; padding: 15px; margin: 10px 0;'>
#   <h3 style='margin-top: 0; color: #1565c0;'>🎯 Analysis</h3>
#   <ul>
#     <li>Examining average annual sales units across market segments, the <strong>budget</strong> segment has the highest average sales value.</li>
#     <li>However, the sales differences between segments are not as pronounced as in the price analysis. The average sales values of the <strong>luxury</strong>, <strong>mid-range</strong>, and <strong>premium</strong> segments are quite close to each other.</li>
#     <li>This result shows that sales performance in the dataset cannot be explained by market segment alone. Brand, model variety, performance features, and other factors may also influence sales volume.</li>
#     <li>When evaluated together with the price analyses, it is seen that lower-priced segments do not always sell significantly more. This shows that the relationship between segment and sales is not as pronounced as that between segment and price.</li>
#   </ul>
# </div>

# %% [markdown]
# # 6. Business Insights

# %% [markdown]
# As a result of this exploratory data analysis, the following key business insights were obtained on the electric vehicle dataset:
#
# - There is a **very strong positive relationship (r = 0.978)** between **battery capacity** and **vehicle range**. This result shows that battery capacity is one of the most important technical factors determining vehicle range.
#
# - **Engine power** has a **more pronounced effect on vehicle price than battery capacity**. While there is a **strong relationship between vehicle price and engine power (r = 0.765)**, the **relationship between battery capacity and price remains quite weak (r = 0.164)**.
#
# - **Vehicles with longer range** tend to receive **higher customer ratings from users (r = 0.668)**. This shows that driving range is one of the important features influencing customer satisfaction.
#
# - **Lucid**, **Porsche**, and **Mercedes** stand out as the brands with the highest average price levels. In contrast, **Volkswagen**, **Tesla**, and **BYD** are among the brands with the highest average sales volume. This finding shows that **a high price does not always mean high sales**.
#
# - Although the **luxury** segment has the highest average vehicle price, the **budget** segment shows the highest average sales value. This shows that price level alone is not sufficient to explain sales performance.
#
# - The numerical variable analyses show that extreme values such as high price, high engine power, and high customer rating in the dataset largely stem from **premium and high-performance vehicles**. Therefore, these observations were not treated as data errors.
#
# - Overall, technical specifications, brand positioning, and market segment jointly influence vehicle price, sales performance, and customer satisfaction. These factors need to be considered together when evaluating the electric vehicle market.

# %% [markdown]
# # 7. Conclusion

# %% [markdown]
# This study carried out a comprehensive exploratory data analysis on the electric vehicle dataset. Data quality was assessed, numerical and categorical variables were examined, relationships between variables were analyzed, and meaningful business insights were obtained. The findings reveal the relationships between vehicle price, range, performance, and sales, while showing that the dataset provides a solid foundation for predictive modeling or business intelligence applications to be carried out in subsequent stages.
